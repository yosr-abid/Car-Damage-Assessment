# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/CopieCarDD_release.zip

# %%
# !pip install ultralytics

# %%
from ultralytics.data.converter import convert_coco
convert_coco(labels_dir='/content/CarDD_release/CarDD_COCO/annotations', use_segments=True)
# Out:
# Annotations /content/CarDD_release/CarDD_COCO/annotations/instances_test2017.json: 100%|██████████| 374/374 [00:00<00:00, 1849.21it/s]
# Annotations /content/CarDD_release/CarDD_COCO/annotations/instances_train2017.json: 100%|██████████| 2816/2816 [00:01<00:00, 2046.53it/s]
# Annotations /content/CarDD_release/CarDD_COCO/annotations/instances_val2017.json: 100%|██████████| 810/810 [00:00<00:00, 2566.48it/s]
# COCO data converted successfully.
# Results saved to /content/coco_converted

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-seg.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='config.yaml', epochs=10, imgsz=640)
# Out:
# Ultralytics YOLOv8.1.4 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import display, Image
Image(filename='/content/runs/segment/train3/confusion_matrix.png', width=1000)

# %%
Image(filename='runs/segment/train3/results.png', width=1000)

# %%
Image(filename='runs/segment/train3/val_batch1_pred.jpg', width=1000)

# %%
import cv2
from google.colab.patches import cv2_imshow
from ultralytics import YOLO
img_pth = "/content/coco_converted/images/test2017/000175.jpg"
model = YOLO("/content/runs/segment/train3/weights/best.pt")
results = model(source=img_pth)
res_plotted = results[0].plot()
cv2_imshow(res_plotted)
cv2.waitKey(0)
# Out:
# image 1/1 /content/coco_converted/images/test2017/000175.jpg: 448x640 1 glass shatter, 16.0ms
# Speed: 2.1ms preprocess, 16.0ms inference, 3.2ms postprocess per image at shape (1, 3, 448, 640)
# <PIL.Image.Image image mode=RGB size=1000x667>
# -1
